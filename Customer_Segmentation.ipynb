# %% [markdown]
# # Problem Statment
# Customer Segmentation Analysis:
# Customer segmentation is the problem of uncovering information about a firm's customer base, based on their interactions with the business. In most cases this interaction is in terms of their purchase behavior and patterns. We explore some of the ways in which this can be used.
#
# You own the mall and want to understand the customers like who can be easily converge [Target Customers] so that the sense can be given to marketing team and plan the strategy accordingly.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
data = pd.read_csv('/content/drive/MyDrive/Mall_Customers.csv')
data.head()
# Out:
#    CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0           1    Male   19                  15                      39
# 1           2    Male   21                  15                      81
# 2           3  Female   20                  16                       6
# 3           4  Female   23                  16                      77
# 4           5  Female   31                  17                      40

# %%
data.shape
# Out:
# (200, 5)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 5 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   CustomerID              200 non-null    int64
#  1   Gender                  200 non-null    object
#  2   Age                     200 non-null    int64
#  3   Annual Income (k$)      200 non-null    int64
#  4   Spending Score (1-100)  200 non-null    int64
# dtypes: int64(4), object(1)
# memory usage: 7.9+ KB

# %%
data.describe()
# Out:
#        CustomerID         Age  Annual Income (k$)  Spending Score (1-100)
# count  200.000000  200.000000          200.000000              200.000000
# mean   100.500000   38.850000           60.560000               50.200000
# std     57.879185   13.969007           26.264721               25.823522
# min      1.000000   18.000000           15.000000                1.000000
# 25%     50.750000   28.750000           41.500000               34.750000
# 50%    100.500000   36.000000           61.500000               50.000000
# 75%    150.250000   49.000000           78.000000               73.000000
# max    200.000000   70.000000          137.000000               99.000000

# %%
data.isnull().sum()
# Out:
# CustomerID                0
# Gender                    0
# Age                       0
# Annual Income (k$)        0
# Spending Score (1-100)    0
# dtype: int64

# %%
import  missingno as msno
msno.matrix(data)
# Out:
# <Axes: >

# %% [markdown]
# # ***Data Visuliation & EDA***

# %%
plt.figure(figsize=(16,5))
plt.subplot(1,3,1)
sns.distplot(data['Age'])
plt.title("Age Distribution")
plt.xlabel("Age")
plt.ylabel("Count")


plt.subplot(1,3,2)
sns.distplot(data['Annual Income (k$)'])
plt.title("Annual Income Distribution")
plt.xlabel("Income")
plt.ylabel("Count")

plt.subplot(1,3,3)
sns.distplot(data['Spending Score (1-100)'])
plt.title("Spending score Distribution")
plt.xlabel("Income")
plt.ylabel("Count")
# Out:
# <ipython-input-7-a5ab39bb086a>:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data['Age'])
# <ipython-input-7-a5ab39bb086a>:10: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data['Annual Income (k$)'])
# <ipython-input-7-a5ab39bb086a>:16: UserWarning:
#
# ...

# %%
df = data.groupby('Gender').size()
df
df.plot(kind = 'pie',colors = ['lightgreen','orange'],subplots = True,explode = [0, 0.001], autopct = '%.2f%%', labels = ['Female', 'Male'])
plt.title("Gender Disribution")

plt.show()

# %%
data.hist(figsize=(15,15),bins=20)
plt.show()

# %%
sns.pairplot(data)
plt.show()

# %%
sns.pairplot(data,vars =['Spending Score (1-100)','Annual Income (k$)','Age'],hue='Gender')
plt.show()

# %%
plt.figure(figsize=(16,8))
sns.countplot(x='Age', data=data)
plt.title("Age Distribution")
plt.ylabel("Count")
plt.yticks(range(0, int(data['Age'].value_counts().max()) + 1, 10))  # Set y-axis ticks manually
plt.show()

# %%
plt.figure(figsize=(16,8))
sns.countplot(x=data['Spending Score (1-100)'])

# Rotate and adjust the font size of the x-axis labels
plt.xticks(rotation=90, fontsize=8)

plt.ylabel('Count')
plt.xlabel('Spending Score (1-100)')
plt.title("Spending Score Distribution")

plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(16,8))
sns.countplot(x=data['Annual Income (k$)'])

# Rotate and adjust the font size of the x-axis labels
plt.xticks(rotation=90, fontsize=8)

plt.ylabel('Count')
plt.xlabel('Annual Income (k$)')
plt.title("Spending Score Distribution")

plt.tight_layout()
plt.show()

# %%
# !pip install dabl
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 558.3/558.3 kB 11.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.3/8.3 MB 60.2 MB/s eta 0:00:00
# ...
#   Attempting uninstall: matplotlib
#     Found existing installation: matplotlib 3.7.1
#     Uninstalling matplotlib-3.7.1:
#       Successfully uninstalled matplotlib-3.7.1
# ...

# %%
import dabl
dabl.plot(data,target_col='Spending Score (1-100)')
# Out:
# Target looks like regression
# /usr/local/lib/python3.10/dist-packages/dabl/plot/supervised.py:214: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   medians = X_new.groupby(col)[target_col].median()
# [<Axes: title={'center': 'Target distribution'}, xlabel='Spending Score (1...', ylabel='frequency'>,
#  array([[<Axes: title={'center': 'F=-3.45E-01'}, xlabel='Age', ylabel='Spending Score (1...'>,
#          <Axes: title={'center': 'F=7.84E-03'}, xlabel='Annual Income (k$)'>]],
#        dtype=object),
#  array([[<Axes: title={'center': 'F=5.44E-02'}, xlabel='Spending Score (1-100)', ylabel='Gender'>]],
#        dtype=object)]

# %%
dabl.plot(data,target_col='Annual Income (k$)')
# Out:
# Target looks like regression
# /usr/local/lib/python3.10/dist-packages/dabl/plot/supervised.py:214: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   medians = X_new.groupby(col)[target_col].median()
# [<Axes: title={'center': 'Target distribution'}, xlabel='Annual Income (k$)', ylabel='frequency'>,
#  array([[<Axes: title={'center': 'F=1.98E-02'}, xlabel='Age', ylabel='Annual Income (k$)'>,
#          <Axes: title={'center': 'F=7.84E-03'}, xlabel='Spending Score (1-100)'>]],
#        dtype=object),
#  array([[<Axes: title={'center': 'F=9.21E-03'}, xlabel='Annual Income (k$)', ylabel='Gender'>]],
#        dtype=object)]

# %%
data_1=data.drop(['CustomerID','Gender'],axis=1)

sns.heatmap(data_1.corr(),cmap='Wistia',annot=True)
# Out:
# <Axes: >

# %%
plt.figure(figsize=(16,8))
for gender in ['Male','Female']:
  plt.scatter(x= 'Age',y='Annual Income (k$)',data = data[data['Gender']==gender],s=200,alpha =0.5,label=gender) # This part filters the data DataFrame to include only the rows where the Gender column matches the current value of gender (either 'Male' or 'Female').
plt.xlabel("Age")
plt.ylabel("Annual Income")
plt.title("Age vs Annual Income")
plt.legend()
plt.show()

# %%
plt.figure(figsize=(16,8))
for gender in ['Male','Female']:
  plt.scatter(x= 'Annual Income (k$)',y='Spending Score (1-100)',data = data[data['Gender']==gender],s=200,alpha =0.5,label=gender) # This part filters the data DataFrame to include only the rows where the Gender column matches the current value of gender (either 'Male' or 'Female').
plt.xlabel("Annual Income")
plt.ylabel("Spending Score")
plt.title("Spending Score vs Annual Income")
plt.legend()
plt.show()

# %% [markdown]
# # ***K-means Clustering***

# %%
data.columns
# Out:
# Index(['CustomerID', 'Gender', 'Age', 'Annual Income (k$)',
#        'Spending Score (1-100)'],
#       dtype='object')

# %%
x= data.iloc[:,[3,4]].values
x
# Out:
# array([[ 15,  39],
#        [ 15,  81],
#        [ 16,   6],
#        [ 16,  77],
#        [ 17,  40],
#        [ 17,  76],
#        [ 18,   6],
#        [ 18,  94],
#        [ 19,   3],
#        [ 19,  72],
#        [ 19,  14],
#        [ 19,  99],
#        [ 20,  15],
#        [ 20,  77],
#        [ 20,  13],
#        [ 20,  79],
#        [ 21,  35],
#        [ 21,  66],
#        [ 23,  29],
#        [ 23,  98],
#        [ 24,  35],
#        [ 24,  73],
#        [ 25,   5],
#        [ 25,  73],
#        [ 28,  14],
#        [ 28,  82],
#        [ 28,  32],
#        [ 28,  61],
#        [ 29,  31],
#        [ 29,  87],
#        [ 30,   4],
#        [ 30,  73],
#        [ 33,   4],
#        [ 33,  92],
#        [ 33,  14],
#        [ 33,  81],
#        [ 34,  17],
#        [ 34,  73],
#        [ 37,  26],
#        [ 37,  75],
#        [ 38,  35],
#        [ 38,  92],
#        [ 39,  36],
#        [ 39,  61],
#        [ 39,  28],
#        [ 39,  65],
#        [ 40,  55],
# ...

# %%
from sklearn.cluster import KMeans

# %%
k = []
for i in range(1,11):
  kmeans = KMeans(n_clusters = i, init = 'k-means++',random_state = 0)
  kmeans.fit(x)
  k.append(kmeans.inertia_)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# ...

# %%
plt.plot(range(1,11),k)
plt.title("The Elbow Method")
plt.xlabel("Number of clusters")
plt.ylabel("WCSS")
# Out:
# Text(0, 0.5, 'WCSS')

# %%
model = KMeans(n_clusters = 5, init = 'k-means++',random_state = 0)
y_kmeans = model.fit_predict(x)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)

# %%
plt.figure(1, figsize=(15, 8))
plt.scatter(x[y_kmeans == 0, 0], x[y_kmeans == 0, 1], s=100, c='magenta', label='Cluster 1')  # Cluster 1
plt.scatter(x[y_kmeans == 1, 0], x[y_kmeans == 1, 1], s=100, c='blue', label='Cluster 2')    # Cluster 2
plt.scatter(x[y_kmeans == 2, 0], x[y_kmeans == 2, 1], s=100, c='cyan', label='Cluster 3')    # Cluster 3
plt.scatter(x[y_kmeans == 3, 0], x[y_kmeans == 3, 1], s=100, c='green', label='Cluster 4')   # Cluster 4
plt.scatter(x[y_kmeans == 4, 0], x[y_kmeans == 4, 1], s=100, c='red', label='Cluster 5')     # Cluster 5
plt.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:, 1], s=200, c='black', label='Centroids')  # Centroids
plt.title('K Means Clustering Algorithm')
plt.xlabel('Annual Income (k$)')
plt.ylabel('Spending Score (1-100)')
plt.legend()
plt.show()
